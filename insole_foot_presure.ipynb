# %% [markdown]
# <a href="https://colab.research.google.com/github/boyuan1004/insole_foot_presure/blob/main/insole_foot_presure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/sample_data/foot_presure
# !unzip /content/drive/MyDrive/insole_foot_presure/test.zip -d /content/sample_data/foot_presure/test
# !unzip /content/drive/MyDrive/insole_foot_presure/train.zip -d /content/sample_data/foot_presure/train_image
# !unzip /content/drive/MyDrive/insole_foot_presure/train_20210106.zip -d /content/sample_data/foot_presure/train_20210106
# Out:
# Archive:  /content/drive/MyDrive/insole_foot_presure/test.zip
#    creating: /content/sample_data/foot_presure/test/images/
#   inflating: /content/sample_data/foot_presure/test/images/image_0001.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0002.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0003.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0004.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0005.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0006.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0007.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0008.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0009.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0010.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0011.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0012.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0013.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0014.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0015.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0016.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0017.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0018.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0019.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0020.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0021.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0022.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0023.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0024.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0025.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0026.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0027.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0028.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0029.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0030.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0031.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0032.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0033.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0034.png
#  extracting: /content/sample_data/foot_presure/test/images/image_0035.png
#  extracting: /content/sample_data/foot_presure/test/images/image_0036.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0037.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0038.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0039.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0040.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0041.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0042.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0043.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0044.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0045.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0046.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0047.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0048.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0049.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0050.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0051.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0052.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0053.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0054.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0055.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0056.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0057.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0058.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0059.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0060.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0061.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0062.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0063.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0064.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0065.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0066.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0067.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0068.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0069.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0070.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0071.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0072.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0073.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0074.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0075.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0076.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0077.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0078.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0079.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0080.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0081.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0082.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0083.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0084.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0085.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0086.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0087.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0088.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0089.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0090.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0091.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0092.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0093.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0094.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0095.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0096.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0097.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0098.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0099.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0100.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0101.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0102.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0103.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0104.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0105.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0106.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0107.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0108.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0109.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0110.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0111.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0112.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0113.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0114.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0115.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0116.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0117.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0118.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0119.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0120.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0121.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0122.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0123.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0124.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0125.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0126.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0127.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0128.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0129.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0130.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0131.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0132.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0133.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0134.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0135.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0136.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0137.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0138.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0139.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0140.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0141.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0142.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0143.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0144.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0145.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0146.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0147.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0148.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0149.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0150.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0151.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0152.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0153.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0154.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0155.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0156.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0157.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0158.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0159.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0160.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0161.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0162.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0163.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0164.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0165.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0166.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0167.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0168.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0169.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0170.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0171.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0172.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0173.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0174.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0175.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0176.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0177.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0178.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0179.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0180.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0181.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0182.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0183.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0184.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0185.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0186.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0187.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0188.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0189.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0190.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0191.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0192.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0193.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0194.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0195.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0196.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0197.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0198.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0199.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0200.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0201.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0202.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0203.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0204.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0205.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0206.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0207.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0208.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0209.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0210.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0211.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0212.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0213.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0214.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0215.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0216.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0217.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0218.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0219.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0220.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0221.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0222.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0223.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0224.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0225.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0226.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0227.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0228.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0229.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0230.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0231.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0232.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0233.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0234.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0235.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0236.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0237.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0238.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0239.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0240.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0241.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0242.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0243.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0244.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0245.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0246.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0247.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0248.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0249.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0250.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0251.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0252.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0253.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0254.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0255.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0256.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0257.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0258.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0259.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0260.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0261.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0262.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0263.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0264.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0265.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0266.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0267.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0268.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0269.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0270.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0271.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0272.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0273.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0274.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0275.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0276.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0277.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0278.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0279.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0280.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0281.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0282.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0283.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0284.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0285.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0286.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0287.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0288.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0289.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0290.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0291.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0292.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0293.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0294.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0295.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0296.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0297.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0298.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0299.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0300.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0301.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0302.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0303.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0304.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0305.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0306.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0307.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0308.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0309.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0310.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0311.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0312.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0313.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0314.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0315.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0316.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0317.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0318.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0319.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0320.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0321.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0322.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0323.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0324.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0325.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0326.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0327.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0328.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0329.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0330.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0331.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0332.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0333.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0334.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0335.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0336.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0337.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0338.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0339.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0340.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0341.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0342.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0343.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0344.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0345.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0346.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0347.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0348.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0349.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0350.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0351.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0352.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0353.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0354.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0355.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0356.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0357.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0358.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0359.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0360.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0361.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0362.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0363.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0364.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0365.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0366.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0367.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0368.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0369.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0370.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0371.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0372.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0373.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0374.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0375.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0376.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0377.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0378.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0379.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0380.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0381.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0382.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0383.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0384.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0385.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0386.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0387.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0388.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0389.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0390.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0391.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0392.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0393.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0394.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0395.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0396.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0397.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0398.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0399.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0400.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0401.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0402.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0403.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0404.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0405.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0406.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0407.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0408.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0409.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0410.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0411.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0412.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0413.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0414.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0415.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0416.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0417.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0418.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0419.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0420.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0421.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0422.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0423.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0424.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0425.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0426.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0427.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0428.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0429.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0430.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0431.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0432.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0433.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0434.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0435.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0436.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0437.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0438.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0439.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0440.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0441.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0442.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0443.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0444.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0445.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0446.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0447.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0448.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0449.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0450.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0451.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0452.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0453.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0454.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0455.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0456.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0457.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0458.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0459.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0460.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0461.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0462.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0463.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0464.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0465.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0466.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0467.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0468.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0469.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0470.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0471.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0472.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0473.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0474.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0475.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0476.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0477.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0478.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0479.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0480.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0481.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0482.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0483.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0484.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0485.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0486.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0487.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0488.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0489.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0490.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0491.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0492.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0493.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0494.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0495.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0496.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0497.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0498.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0499.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0500.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0501.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0502.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0503.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0504.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0505.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0506.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0507.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0508.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0509.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0510.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0511.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0512.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0513.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0514.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0515.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0516.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0517.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0518.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0519.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0520.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0521.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0522.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0523.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0524.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0525.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0526.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0527.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0528.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0529.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0530.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0531.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0532.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0533.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0534.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0535.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0536.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0537.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0538.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0539.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0540.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0541.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0542.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0543.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0544.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0545.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0546.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0547.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0548.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0549.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0550.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0551.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0552.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0553.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0554.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0555.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0556.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0557.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0558.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0559.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0560.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0561.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0562.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0563.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0564.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0565.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0566.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0567.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0568.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0569.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0570.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0571.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0572.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0573.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0574.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0575.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0576.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0577.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0578.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0579.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0580.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0581.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0582.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0583.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0584.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0585.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0586.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0587.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0588.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0589.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0590.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0591.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0592.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0593.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0594.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0595.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0596.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0597.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0598.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0599.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0600.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0601.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0602.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0603.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0604.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0605.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0606.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0607.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0608.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0609.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0610.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0611.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0612.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0613.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0614.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0615.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0616.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0617.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0618.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0619.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0620.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0621.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0622.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0623.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0624.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0625.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0626.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0627.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0628.png
#   inflating: /content/sample_data/foot_presure/test/images/image_0629.png
# ...
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0239.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0240.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0241.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0242.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0243.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0244.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0245.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0246.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0247.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0248.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0249.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0250.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0251.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0252.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0253.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0254.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0255.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0256.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0257.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0258.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0259.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0260.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0261.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0262.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0263.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0264.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0265.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0266.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0267.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0268.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0269.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0270.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0271.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0272.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0273.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0274.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0275.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0276.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0277.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0278.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0279.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0280.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0281.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0282.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0283.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0284.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0285.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0286.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0287.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0288.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0289.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0290.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0291.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0292.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0293.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0294.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0295.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0296.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0297.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0298.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0299.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0300.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0301.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0302.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0303.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0304.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0305.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0306.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0307.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0308.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0309.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0310.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0311.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0312.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0313.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0314.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0315.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0316.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0317.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0318.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0319.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0320.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0321.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0322.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0323.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0324.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0325.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0326.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0327.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0328.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0329.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0330.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0331.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0332.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0333.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0334.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0335.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0336.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0337.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0338.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0339.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0340.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0341.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0342.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0343.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0344.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0345.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0346.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0347.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0348.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0349.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0350.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0351.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0352.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0353.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0354.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0355.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0356.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0357.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0358.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0359.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0360.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0361.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0362.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0363.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0364.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0365.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0366.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0367.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0368.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0369.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0370.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0371.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0372.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0373.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0374.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0375.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0376.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0377.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0378.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0379.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0380.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0381.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0382.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0383.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0384.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0385.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0386.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0387.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0388.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0389.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0390.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0391.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0392.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0393.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0394.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0395.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0396.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0397.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0398.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0399.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0400.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0401.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0402.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0403.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0404.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0405.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0406.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0407.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0408.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0409.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0410.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0411.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0412.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0413.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0414.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0415.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0416.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0417.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0418.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0419.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0420.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0421.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0422.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0423.jpg
#   inflating: /content/sample_data/foot_presure/train_20210106/images/image_0424.jpg

# %% [markdown]
# # Setup

# %%
# WandB – Install the W&B library
# !pip install wandb -q
# !pip install patool
# !pip install torchinfo
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 16.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.4 MB/s eta 0:00:00
# Collecting patool
#   Downloading patool-2.2.0-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-2.2.0
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
from __future__ import print_function
import argparse
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io, transform
import matplotlib.image as mpimg
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, utils, models
#ignore excessive warnings
import logging
logging.propagate = False
logging.getLogger().setLevel(logging.ERROR)

import cv2
import wandb

# %%
# WandB – Login to your wandb account so you can log all your metrics
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# # prepare dataset

# %%
#load datset into Notebook
import patoolib
import pathlib
from pathlib import Path
import shutil


# Source and destination paths
train_source_dir = Path('/content/sample_data/foot_presure/train_image/images')
train_dest_dir = Path('/content/sample_data/foot_presure/train_image')

test_source_dir = Path('/content/sample_data/foot_presure/test/images')
test_dest_dir = Path('/content/sample_data/foot_presure/test')

# Move files from train_source_dir to train_dest_dir
for file_path in train_source_dir.iterdir():
    shutil.move(str(file_path), str(train_dest_dir))

# Move files from test_source_dir to test_dest_dir
for file_path in test_source_dir.iterdir():
    shutil.move(str(file_path), str(test_dest_dir))

# %%
#combine new and old train data
def get_new_file_name(file_name):
    file_name = file_name.split('.')
    assert len(file_name) == 2
    return file_name[0] + "_1" + "." + file_name[1]




new_data_path = Path('/content/sample_data/foot_presure/train_20210106')
dest_data_path = Path('/content/sample_data/foot_presure/train_image')


for p in (new_data_path/'images').glob('image_*'):
    p.rename(Path(dest_data_path, get_new_file_name(p.name)))
print(len(list(dest_data_path.glob('image_*'))))


dest_annotation_df= pd.read_csv('/content/sample_data/foot_presure/train_image/annotation.csv')
new_annotation_df  = pd.read_csv('/content/sample_data/foot_presure/train_20210106/annotation.csv')
new_annotation_df['images'] = new_annotation_df['images'].apply(get_new_file_name)
annotation_df = pd.concat([dest_annotation_df, new_annotation_df], ignore_index=True)

test_img_path = Path('/content/sample_data/foot_presure/test')
test_image_names = sorted([p.name for p in test_img_path.glob('image_*')])
test_annotation_df = pd.DataFrame({'images': test_image_names})
# Out:
# 1424

# %%
#檢測是否正確存入
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):

    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
train_img_path = Path('/content/sample_data/foot_presure/train_image')
walk_through_dir(train_img_path)
walk_through_dir(test_img_path)
# Out:
# There are 1 directories and 1425 images in '/content/sample_data/foot_presure/train_image'.
# There are 0 directories and 0 images in '/content/sample_data/foot_presure/train_image/images'.
# There are 1 directories and 1000 images in '/content/sample_data/foot_presure/test'.
# There are 0 directories and 0 images in '/content/sample_data/foot_presure/test/images'.

# %%
#find block dots for train, valid set

def find_black_dot(img):
  kernel = np.ones((8,8), dtype="float")
  BLACK_THR = 20
  KERNEL_THR = 2.2*5*5 + 1.5*(8*8-5*5)
  img_black = np.sum(img <= BLACK_THR, axis=2)
  img_filtered = cv2.filter2D(img_black, 1, kernel)
  img_dot_mask = img_filtered >= KERNEL_THR
  dot_i, dot_j = np.where(img_dot_mask)
  dot_i, dot_j = int(np.median(dot_i)), int(np.median(dot_j))
  return (dot_j, dot_i)

dot_list = [find_black_dot(io.imread(train_img_path / f)) for f in annotation_df.images]
dot_list_trans = list(zip(*dot_list))
annotation_df['dot_x'] = dot_list_trans[0]
annotation_df['dot_y'] = dot_list_trans[1]
print(annotation_df.head())
print()
# find black dots for test set
print(len(test_image_names))
dot_list = [find_black_dot(io.imread(test_img_path / f)) for f in test_image_names]
dot_list_trans = list(zip(*dot_list))
test_annotation_df['dot_x'] = dot_list_trans[0]
test_annotation_df['dot_y'] = dot_list_trans[1]
print(test_annotation_df.head())
# Out:
#            images  x1   y1  x2   y2  dot_x  dot_y
# 0  image_0001.png  55  136  75  383     52    275
# 1  image_0002.png  62  139  42  385     67    286
# 2  image_0003.png  47  117  76  368     52    254
# 3  image_0004.png  66  119  37  376     65    246
# 4  image_0005.png  58  147  85  381     54    276
#
# 1000
#            images  dot_x  dot_y
# 0  image_0001.png     58    282
# 1  image_0002.png     59    279
# 2  image_0003.png     52    292
# 3  image_0004.png     65    275
# 4  image_0005.png     55    267

# %%
# 120 * 400 * 3
X_CROP_LOWER, X_CROP_UPPER = (3, 8) # 120
Y_CROP_LOWER, Y_CROP_UPPER = (79, 5) # 400
# note: width of upper and lower should logically be the same
split_crop = {
    'upper': {'x': X_CROP_LOWER, 'y': Y_CROP_LOWER, 'width': 120-X_CROP_LOWER-X_CROP_UPPER, 'height': 120},
    'lower': {'x': X_CROP_LOWER, 'y': 400-Y_CROP_UPPER-75, 'width': 120-X_CROP_LOWER-X_CROP_UPPER, 'height': 95}
}
assert split_crop['upper']['width'] == split_crop['lower']['width']

def check_annotation_range(x1, y1, x2, y2):
    # upper box check
    b = x1 < split_crop['upper']['x'] + split_crop['upper']['width']
    b = b and x1 > split_crop['upper']['x']
    b = b and y1 < split_crop['upper']['y'] + split_crop['upper']['height']
    b = b and y1 > split_crop['upper']['y']
    # lower box check
    b = b and x2 < split_crop['lower']['x'] + split_crop['lower']['width']
    b = b and x2 > split_crop['lower']['x']
    b = b and y2 < split_crop['lower']['y'] + split_crop['lower']['height']
    b = b and y2 > split_crop['lower']['y']
    return b

assert annotation_df['x1'].max() < split_crop['upper']['x'] + split_crop['upper']['width']
assert annotation_df['x1'].min() > split_crop['upper']['x']
assert annotation_df['y1'].max() < split_crop['upper']['y'] + split_crop['upper']['height']
assert annotation_df['y1'].min() > split_crop['upper']['y']
assert annotation_df['x2'].max() < split_crop['lower']['x'] + split_crop['lower']['width']
assert annotation_df['x2'].min() > split_crop['lower']['x']
assert annotation_df['y2'].max() < split_crop['lower']['y'] + split_crop['lower']['height']
assert annotation_df['y2'].min() > split_crop['lower']['y']

# %%
#visualize foot and it's label
def show_foot(image: np.ndarray, annotations: dict=None, predictions: dict=None, black_dot: dict=None, split_crop: dict=None):
    """Show image with landmarks"""
    """split_crop: {'upper': {'x': int, 'y': int, 'width': int, 'height': int}, 'lower': {'x': int, 'y': int, 'width': int, 'height': int}}"""
    plt.figure(figsize = (6.4*1.5,4.8*1.5))
    plt.imshow(image)
    if annotations:
        plt.scatter(annotations['x1'], annotations['y1'], s=30, marker='s', c='white', edgecolors='black')
        plt.scatter(annotations['x2'], annotations['y2'], s=30, marker='s', c='lightgreen', edgecolors='black')
    if predictions:
        if predictions.get('upper') is not None:
            plt.scatter(predictions['upper'][0], predictions['upper'][1], s=15, marker='s', c='gold', edgecolors='black')
        if predictions.get('lower') is not None:
            plt.scatter(predictions['lower'][0], predictions['lower'][1], s=15, marker='s', c='gold', edgecolors='black')
    if black_dot:
        plt.scatter(black_dot['dot_x'], black_dot['dot_y'], s=20, marker='o', c='red', edgecolors='white')
    if split_crop:
        plt.hlines(y = split_crop['upper']['y'],
              xmin = split_crop['upper']['x'],
              xmax = split_crop['upper']['x'] + split_crop['upper']['width'],
              colors = 'grey', linestyles = 'solid')
        plt.hlines(y = split_crop['upper']['y'] + split_crop['upper']['height'],
              xmin = split_crop['upper']['x'],
              xmax = split_crop['upper']['x'] + split_crop['upper']['width'],
              colors = 'grey', linestyles = 'solid')
        plt.vlines(x = split_crop['upper']['x'],
              ymin = split_crop['upper']['y'],
              ymax = split_crop['upper']['y'] + split_crop['upper']['height'],
              colors = 'grey', linestyles = 'solid')
        plt.vlines(x = split_crop['upper']['x'] + split_crop['upper']['width'],
              ymin = split_crop['upper']['y'],
              ymax = split_crop['upper']['y'] + split_crop['upper']['height'],
              colors = 'grey', linestyles = 'solid')
        plt.text(x = split_crop['upper']['x'], y = split_crop['upper']['y'], s = 'UPPER', color = 'red')
        #
        plt.hlines(y = split_crop['lower']['y'],
              xmin = split_crop['lower']['x'],
              xmax = split_crop['lower']['x'] + split_crop['lower']['width'],
              colors = 'grey', linestyles = 'solid')
        plt.hlines(y = split_crop['lower']['y'] + split_crop['lower']['height'],
              xmin = split_crop['lower']['x'],
              xmax = split_crop['lower']['x'] + split_crop['lower']['width'],
              colors = 'grey', linestyles = 'solid')
        plt.vlines(x = split_crop['lower']['x'],
              ymin = split_crop['lower']['y'],
              ymax = split_crop['lower']['y'] + split_crop['lower']['height'],
              colors = 'grey', linestyles = 'solid')
        plt.vlines(x = split_crop['lower']['x'] + split_crop['lower']['width'],
              ymin = split_crop['lower']['y'],
              ymax = split_crop['lower']['y'] + split_crop['lower']['height'],
              colors = 'grey', linestyles = 'solid')
        plt.text(x = split_crop['lower']['x'], y = split_crop['lower']['y'], s = 'LOWER', color = 'red')
    plt.pause(0.001)  # pause a bit so that plots are updated
    plt.show()

{'image_0980.png',}
img_name = 'image_0083.png'
img_annotation = annotation_df[annotation_df.images == img_name].to_dict('records')[0]
show_foot(
    io.imread(Path(train_img_path) / img_name),
    annotations = img_annotation,
    black_dot = img_annotation,
    split_crop = split_crop
    )

# %% [markdown]
# #data Augmentation

# %%
# !pip install -U albumentations --quiet
# !git clone https://github.com/KuanHaoHuang/AIdea-foot-image-analysis
# !ls AIdea-foot-image-analysis/
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 51.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 91.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 36.6 MB/s eta 0:00:00
# Cloning into 'AIdea-foot-image-analysis'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 38 (delta 5), reused 28 (delta 2), pack-reused 0
# Receiving objects: 100% (38/38), 1.57 MiB | 13.27 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# aidea_aso_foot_image_analysis.ipynb		 LICENSE	    sample_train_data
# demo						 my_submission.csv  simple_average_ensemble.R
# image_keypoint_data_augmentation_tutorial.ipynb  README.md

# %%
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import albumentations as A
image_path = Path("/content/sample_data/foot_presure/train_image")
annotation_o = pd.read_csv("/content/sample_data/foot_presure/train_image/annotation.csv")
# Out:
# <ipython-input-14-0174bed4edab>:1: DeprecationWarning: Please use `map_coordinates` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   from scipy.ndimage.interpolation import map_coordinates
# <ipython-input-14-0174bed4edab>:2: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
img_name = "image_0001.png"
img = io.imread(image_path / img_name)
print("\nOriginal Image")
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(img)
plt.show()
print("\nTransformed Image")
trafo = A.ShiftScaleRotate(border_mode=cv2.BORDER_CONSTANT, value=[255,255,255])
trafo_img = trafo(image=img)['image']
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(trafo_img)
plt.show()
# Out:
# Original Image
# Transformed Image

# %%
# albumentations 範例：垂直與水平翻轉 with landmarks旋轉
img_name = "image_0001.png"
img = io.imread(image_path / img_name)
annot = annotation_o[annotation_o['images']==img_name].to_dict('records')[0]
print(annot)
annot = [annot['x1'], annot['x2']], [annot['y1'], annot['y2']]
print("\nOriginal image")
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(img)
plt.scatter(*annot, s=35, marker='s', c='white', edgecolors='black')
plt.show()
print("\nTransformed image, without keypoints transformation")
trafo = A.Flip(p=1.0)
trafo_img = trafo(image=img)['image']
plt.figure(figsize=(6.4*1.2, 4.8*1.2))
plt.imshow(img)
plt.scatter(*annot, s=35, marker='s', c='white', edgecolors='black')
plt.show()
print("\nTransformed image and keypoints")
trafo = A.Compose([A.Flip(p=1.0)], keypoint_params = A.KeypointParams(format='xy'))
trafo_obj = trafo(image=img, keypoints=list(zip(*annot)))
trafo_img , trafo_keypts = trafo_obj['image'], trafo_obj['keypoints']
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(trafo_img)
plt.scatter(*list(zip(*trafo_keypts)), s=35, marker='s', c='white', edgecolors='black')
plt.show()
# Out:
# {'images': 'image_0001.png', 'x1': 55, 'y1': 136, 'x2': 75, 'y2': 383}
#
# Original image
# Transformed image, without keypoints transformation
# Transformed image and keypoints

# %%
class RandomCoarseDropout():
    def __init__(self, prob=0.5):
        self.prob = prob
        self.trafo = A.CoarseDropout(always_apply=True, max_height=17, max_width=17, min_height=6, min_width=6, min_holes=5, max_holes=10, fill_value=(255,255,255))

    def __call__(self, sample):
        file_name, image, dot, annotations = sample['file_name'], sample['image'], sample['dot'], sample['annotations']
        if random.random() < self.prob:
            image = {k: self.trafo(image=v)['image'] for k, v in image.items()}
        sample = {'file_name': file_name, 'image': image, 'dot': dot, 'annotations': annotations}
        return sample

# %%
#ElasticTransform
img_name = "image_0001.png"
img = io.imread(image_path / img_name)
annot = annotation_o[annotation_o['images']==img_name].to_dict('records')[0]
print(annot)
RANDOM_SEED = 52
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED )

#以矩陣形式表示兩個 keypoints 位置
mask1 = np.zeros((*img.shape[:2],1))
mask1[int(annot['y1']), int(annot['x1'])] = 1
mask2 = np.zeros((*img.shape[:2], 1))
mask2[int(annot['y2']), int(annot['x2'])] = 1

height, width = img.shape[:2]
center_square = np.float32((height, width)) // 2
square_size = min((height, width)) // 3
pts1 = np.float32(
    [
        center_square + square_size,
        [center_square[0] + square_size, center_square[1] - square_size],
        center_square - square_size,
    ]
)
alpha_affine = float(random.random()*5)
pts2 = pts1 + np.random.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
matrix = cv2.getAffineTransform(pts1, pts2)

random_state = np.random.RandomState(None)
alpha = 80
sigma = 8
dx = np.float32(gaussian_filter((random_state.rand(height, width) * 2 - 1), sigma) * alpha)
dy = np.float32(gaussian_filter((random_state.rand(height, width) * 2 - 1), sigma) * alpha)
x, y = np.meshgrid(np.arange(width), np.arange(height))
map_x = np.float32(x + dx)
map_y = np.float32(y + dy)


print("\nOriginal Image")
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(img)
plt.scatter([annot['x1'], annot['x2']], [annot['y1'], annot['y2']], s=35, marker='s', c='white', edgecolors='black')
plt.show()
print("\nAugmented Image and keypoints")
trafo_img = cv2.warpAffine(img,
                           M = matrix,dsize=(width, height),
                           flags = cv2.INTER_LINEAR,borderMode=cv2.BORDER_CONSTANT ,borderValue=(255,255,255)
                           )
trafo_img = cv2.remap(trafo_img, map_x, map_y, interpolation=cv2.INTER_LINEAR,borderValue=0, borderMode=cv2.BORDER_REFLECT_101)
trafo_mask1 = cv2.warpAffine(mask1,
                             M=matrix, dsize=(width,height),
                             flags=cv2.INTER_LINEAR,borderMode=cv2.BORDER_CONSTANT ,borderValue=(0,0,0)
                              )
trafo_mask1 = cv2.remap(trafo_mask1, map_x, map_y, interpolation=cv2.INTER_LINEAR, borderValue= 0, borderMode=cv2.BORDER_REFLECT_101)
trafo_mask2 = cv2.warpAffine(mask2,
            M=matrix, dsize=(width, height),
            flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=(0,0,0)
        )
trafo_mask2 = cv2.remap(trafo_mask2, map_x, map_y, interpolation=cv2.INTER_LINEAR, borderValue= 0, borderMode=cv2.BORDER_REFLECT_101)
mask1_y, mask1_x = np.where(trafo_mask1)[0].mean(), np.where(trafo_mask1)[1].mean()
mask2_y, mask2_x = np.where(trafo_mask2)[0].mean(), np.where(trafo_mask2)[1].mean()
plt.figure(figsize = (6.4*1.2,4.8*1.2))
plt.imshow(trafo_img)
plt.scatter([mask1_x, mask2_x], [mask1_y, mask2_y], s=35, marker='s', c='white', edgecolors='black')
plt.show()
# Out:
# {'images': 'image_0001.png', 'x1': 55, 'y1': 136, 'x2': 75, 'y2': 383}
#
# Original Image
# Augmented Image and keypoints

# %%
#ElasticTransform function 實作
def _translate_mask(mask):
  mask_y = np.where(mask)[0]
  mask_x = np.where(mask)[1]
  if len(mask_x) == 0 or len(mask_y) == 0:
    return None
  else:
    return (mask_x.mean(), mask_y.mean())

def elastic(img, annot, dot, pred = None):
  has_pred = pred is not None
  height, width = img.shape[:2]
  mask1 = np.zeros((*img.shape[:2], 1))
  mask1[int(round(annot[0][1])), int(round(annot[0][0]))] = 1
  mask2 = np.zeros((*img.shape[:2], 1))
  mask2[int(round(annot[1][1])), int(round(annot[1][0]))] = 1
  mask_dot = np.zeros((*img.shape[:2], 1))
  mask_dot[int(round(dot[1])), int(round(dot[0]))] = 1
  img_ori = np.array(img, copy=True)
  mask1_ori = np.array(mask1, copy=True)
  mask2_ori = np.array(mask2, copy=True)
  mask_dot_ori = np.array(mask_dot, copy=True)
  #Random affine
  center_square = np.float32((height, width)) //2
  square_size = min((height, width)) //3
  pts1 = np.float32(
      [
          center_square + square_size,
          [center_square[0] + square_size, center_square[1] - square_size],
          center_square - square_size
      ]
  )
  if_retry = True
  while if_retry:
    img = np.array(img_ori, copy=True)
    mask1 = np.array(mask1_ori, copy=True)
    mask2 = np.array(mask2_ori, copy=True)
    mask_dot = np.array(mask_dot_ori, copy=True)
    alpha_affine = float(random.random()*15)
    pts2 = pts1 + np.random.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
    matrix = cv2.getAffineTransform(pts1, pts2)
    img = cv2.warpAffine(img,
            M=matrix, dsize=(width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=(255,255,255)
        )
    mask1 = cv2.warpAffine(mask1,
            M=matrix, dsize=(width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=(0,0,0)
        )
    mask2 = cv2.warpAffine(mask2,
            M=matrix, dsize=(width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=(0,0,0)
        )
    mask_dot = cv2.warpAffine(mask_dot,
            M=matrix, dsize=(width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=(0,0,0)
        )
    mask1 = _translate_mask(mask1)
    mask2 = _translate_mask(mask2)
    mask_dot = _translate_mask(mask_dot)
    if mask1 is None or mask2 is None or mask_dot is None:
            continue
    else:
          if_retry = False
    new_x1, new_y1 = mask1
    new_x2, new_y2 = mask2
    new_dot_x, new_dot_y = mask_dot
    return img, np.array([[new_x1, new_y1, new_x2, new_y2]]).astype('float32'), np.array([new_dot_x, new_dot_y]).astype('float32')

img_name = 'image_0201_1.jpg'
img_annotation = annotation_df[annotation_df.images == img_name].to_dict('records')[0]
print(img_annotation)
img = io.imread(Path('/content/sample_data/foot_presure/train_image') / img_name)
img, annot, dot = elastic(img, np.array([[img_annotation['x1'], img_annotation['y1']], [img_annotation['x2'], img_annotation['y2']]]), np.array([img_annotation['dot_x'], img_annotation['dot_y']]))

print(img.shape)
plt.imshow(img)
plt.scatter(annot[:,0], annot[:,1], s=30, marker='s', c='white', edgecolors='black')
plt.scatter(dot[0], dot[1], s=15, marker='o', c='red', edgecolors='white')
plt.show()
# Out:
# {'images': 'image_0201_1.jpg', 'x1': 62, 'y1': 154, 'x2': 86, 'y2': 382, 'dot_x': 54, 'dot_y': 287}
# (400, 120, 3)

# %% [markdown]
# #prepare dataset

# %%
#transform & create dataset
transform = transforms.Compose(
    [transforms.ToTensor(),
     RandomCoarseDropout(0.6),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

class Insolefoot_dataset(Dataset):

  def __init__(self, transforms = None):
    self.annotation_df = annotation_df.copy()
    self.test_annotation_df = test_annotation_df.copy()
    self.train_img = Path(train_img_path)
    self.test_img = Path(test_img_path)
    REMOVE_FILES = {'image_0980.png', 'image_0749.png', 'image_0751.png', 'image_0147.png', 'image_0747.png'}
    self.train_img_list = [f for f in sorted(list(self.train_img.glob('image_*'))) if f.name not in REMOVE_FILES]
    self.annotation_df = self.annotation_df[~self.annotation_df['images'].isin(REMOVE_FILES)]
    self.transform = transform

  def update_remove_file(self, file_list):
    self.train_img_list = [f for f in self.train_img_list if f.name not in file_list]
    self.annotation_df = self.annotation_df[~self.annotation_df['images'].isin(file_list)]


  def __len__(self):
    return len(self.train_img_list)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()[0]
    img_name = self.train_img_list[idx].name
    img_path = self.train_img / img_name
    img_record = self.annotation_df[self.annotation_df.images == img_name].to_dict('records')[0]
    image = io.imread(img_path)
    sample = {'file_name': img_name, 'image': image,
              'dot': np.array([img_record[k] for k in ['dot_x', 'dot_y']])}
    annotations = np.array([img_record[k] for k in ['x1', 'y1', 'x2', 'y2']])
    annotations = annotations.astype('float').reshape(-1, 2)
    sample['annotations'] = annotations
    if self.transform:
      sample['image'], sample['annotations'], sample['dot'] = elastic(sample['image'], np.array([[img_record['x1'], img_record['y1']], [img_record['x2'], img_record['y2']]]), np.array([img_record['dot_x'], img_record['dot_y']]))
      sample['image'] = self.transform(sample['image'])  # Changed from transform to self.transform


    return sample

# %%
class Insolefoot_test_dataset(Dataset):

  def __init__(self, transforms = None):
    self.test_annotation_df = test_annotation_df.copy()
    self.test_img = Path(test_img_path)
    self.test_img_list = (sorted(list(self.test_img.glob('image_*'))))
    self.transform = transform

  def __len__(self):
    return len(self.test_img_list)

  def __getitem__(self, idx):
    if torch.is_tensor(idx):
      idx = idx.tolist()[0]
    img_name = self.test_img_list[idx].name
    img_path = self.test_img / img_name
    img_record = self.test_annotation_df[self.test_annotation_df.images == img_name].to_dict('records')[0]
    image = io.imread(img_path)
    sample = {'file_name': img_name, 'image': image,
              'dot': np.array([img_record[k] for k in ['dot_x', 'dot_y']])}
    if self.transform:
      sample['image'] = self.transform(sample['image'])  # Changed from transform to self.transform


    return sample

# %%
foot_dataset = Insolefoot_dataset(transforms=transform)
test_dataset = Insolefoot_test_dataset(transforms = transform)
print(len(foot_dataset))
len_valid_set = int(0.1*len(foot_dataset))
len_train_set = len(foot_dataset) - len_valid_set
train_dataset, valid_dataset = torch.utils.data.random_split(foot_dataset, [len_train_set, len_valid_set])
# Out:
# 1419

# %%
print(len(train_dataset))
print(len(valid_dataset))
print(len(test_dataset))
# Out:
# 1278
# 141
# 1000

# %% [markdown]
# # Densenet implement

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(BasicBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, training=self.training)
        return torch.cat([x, out], 1)

class BottleneckBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(BottleneckBlock, self).__init__()
        inter_planes = out_planes * 4
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, inter_planes, kernel_size=1, stride=1,
                               padding=0, bias=False)
        self.bn2 = nn.BatchNorm2d(inter_planes)
        self.conv2 = nn.Conv2d(inter_planes, out_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        out = self.conv2(self.relu(self.bn2(out)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        return torch.cat([x, out], 1)

class TransitionBlock(nn.Module):
    def __init__(self, in_planes, out_planes, dropRate=0.0):
        super(TransitionBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=1,
                               padding=0, bias=False)
        self.droprate = dropRate
    def forward(self, x):
        out = self.conv1(self.relu(self.bn1(x)))
        if self.droprate > 0:
            out = F.dropout(out, p=self.droprate, inplace=False, training=self.training)
        return F.avg_pool2d(out, 2)

class DenseBlock(nn.Module):
    def __init__(self, nb_layers, in_planes, growth_rate, block, dropRate=0.0):
        super(DenseBlock, self).__init__()
        self.layer = self._make_layer(block, in_planes, growth_rate, nb_layers, dropRate)
    def _make_layer(self, block, in_planes, growth_rate, nb_layers, dropRate):
        layers = []
        for i in range(nb_layers):
            layers.append(block(in_planes+i*growth_rate, growth_rate, dropRate))
        return nn.Sequential(*layers)
    def forward(self, x):
        return self.layer(x)

class DenseNet3(nn.Module):
    def __init__(self, depth, num_classes=4, growth_rate=12,
                 reduction=0.5, bottleneck=True, dropRate=0.0):
        super(DenseNet3, self).__init__()
        in_planes = 2 * growth_rate
        n = (depth - 4) / 3
        if bottleneck == True:
            n = n/2
            block = BottleneckBlock
        else:
            block = BasicBlock
        n = int(n)
        # 1st conv before any dense block
        self.conv1 = nn.Conv2d(3, in_planes, kernel_size=3, stride=1,
                               padding=1, bias=False)
        # 1st block
        self.block1 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        self.trans1 = TransitionBlock(in_planes, int(math.floor(in_planes*reduction)), dropRate=dropRate)
        in_planes = int(math.floor(in_planes*reduction))
        # 2nd block
        self.block2 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        self.trans2 = TransitionBlock(in_planes, int(math.floor(in_planes*reduction)), dropRate=dropRate)
        in_planes = int(math.floor(in_planes*reduction))
        # 3rd block
        self.block3 = DenseBlock(n, in_planes, growth_rate, block, dropRate)
        in_planes = int(in_planes+n*growth_rate)
        # global average pooling and classifier
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(in_planes, num_classes)
        self.in_planes = in_planes

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()



    def forward(self, x):
        out = self.conv1(x)
        out = self.trans1(self.block1(out))
        out = self.trans2(self.block2(out))
        out = self.block3(out)
        out = self.relu(self.bn1(out))
        out = F.avg_pool2d(out, 8)
        out = out.view(-1, self.in_planes)
        return self.fc(out)

# %% [markdown]
# #efficientnet

# %%
import torchvision.models as models
class BaseModule(nn.Module):
  def __init__(self, learning_rate=None ):
    super(BaseModule, self).__init__()
    efficientnet_module = models.efficientnet_b0(pretrained=False)
    efficientnet_module_conv = nn.Sequential(*list(efficientnet_module.children())[:-2])
    self.backbone = efficientnet_module_conv

    self.fc = nn.Sequential(
            nn.Linear(66562, 512),
            nn.BatchNorm1d(512),
            nn.GELU(),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.GELU(),
            nn.Linear(128, 32),
            nn.BatchNorm1d(32),
            nn.GELU(),
            nn.Linear(32, 4))


  def forward(self, img, dot):
    img_conv = self.backbone(img)
    img_conv = img_conv.view(img_conv.size(0), -1)  # Assuming img_conv is of shape [batch_size, 1000]
    # Concatenate img_conv and dot
    concatenated_tensor = torch.cat((img_conv, dot), dim=1)  # Assuming dot is of shape [batch_size, 2]
    #print(self.flatten(img_conv).shape)
    #print(dot.shape)
    out = self.fc(concatenated_tensor)

    return out

# %%
from torchinfo import summary
efficientnet_module = models.efficientnet_b0(pretrained=False)
efficientnet_module_conv = nn.Sequential(*list(efficientnet_module.children())[:-2])
summary(model=efficientnet_module_conv,
        input_size=(32, 3, 224,224),
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# Sequential (Sequential)                                      [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# ├─Sequential (0)                                             [32, 3, 224, 224]    [32, 1280, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [32, 3, 224, 224]    [32, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [32, 3, 224, 224]    [32, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [32, 32, 112, 112]   [32, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [32, 32, 112, 112]   [32, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [32, 32, 112, 112]   [32, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [32, 32, 112, 112]   [32, 16, 112, 112]   1,448                True
# │    └─Sequential (2)                                        [32, 16, 112, 112]   [32, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [32, 16, 112, 112]   [32, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [32, 24, 56, 56]     [32, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [32, 24, 56, 56]     [32, 40, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [32, 24, 56, 56]     [32, 40, 28, 28]     15,350               True
# │    │    └─MBConv (1)                                       [32, 40, 28, 28]     [32, 40, 28, 28]     31,290               True
# │    └─Sequential (4)                                        [32, 40, 28, 28]     [32, 80, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [32, 40, 28, 28]     [32, 80, 14, 14]     37,130               True
# │    │    └─MBConv (1)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    │    └─MBConv (2)                                       [32, 80, 14, 14]     [32, 80, 14, 14]     102,900              True
# │    └─Sequential (5)                                        [32, 80, 14, 14]     [32, 112, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [32, 80, 14, 14]     [32, 112, 14, 14]    126,004              True
# │    │    └─MBConv (1)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    │    └─MBConv (2)                                       [32, 112, 14, 14]    [32, 112, 14, 14]    208,572              True
# │    └─Sequential (6)                                        [32, 112, 14, 14]    [32, 192, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 112, 14, 14]    [32, 192, 7, 7]      262,492              True
# │    │    └─MBConv (1)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (2)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    │    └─MBConv (3)                                       [32, 192, 7, 7]      [32, 192, 7, 7]      587,952              True
# │    └─Sequential (7)                                        [32, 192, 7, 7]      [32, 320, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [32, 192, 7, 7]      [32, 320, 7, 7]      717,232              True
# │    └─Conv2dNormActivation (8)                              [32, 320, 7, 7]      [32, 1280, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [32, 320, 7, 7]      [32, 1280, 7, 7]     409,600              True
# │    │    └─BatchNorm2d (1)                                  [32, 1280, 7, 7]     [32, 1280, 7, 7]     2,560                True
# │    │    └─SiLU (2)                                         [32, 1280, 7, 7]     [32, 1280, 7, 7]     --                   --
# ============================================================================================================================================
# Total params: 4,007,548
# Trainable params: 4,007,548
# Non-trainable params: 0
# Total mult-adds (G): 12.31
# ============================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 3452.09
# Params size (MB): 16.03
# Estimated Total Size (MB): 3487.39
# ============================================================================================================================================

# %% [markdown]
# #Define the Training Loop

# %%
import sys

def print_overwrite(step, total_step, loss, operation):
    sys.stdout.write('\r')
    if operation == 'train':
        sys.stdout.write("Train Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))
    else:
        sys.stdout.write("Valid Steps: %d/%d  Loss: %.4f " % (step, total_step, loss))

    sys.stdout.flush()

# %%
def euclidean_distance_loss(prediction, ground_truth):
        diff = prediction.view(-1, 2) - ground_truth.view(-1, 2)
        eu_dist = torch.sqrt(torch.sum(torch.pow(diff, 2), dim=1))
        return torch.mean(eu_dist)

def train(args, model ,device, train_loader,valid_loader, optimizer, epoch):

    loss_train = 0
    loss_valid = 0
    running_loss = 0
    example_images = []
    model.train()

    for step in range(1, len(train_loader)+1):
      sample = next(iter(train_loader))

      images = sample['image'].cuda()
      dots = sample['dot'].cuda()
      landmarks = sample['annotations'].cuda()
      landmarks = landmarks.view(32,-1)
      #print(landmarks)
      predictions = model(images,dots)
      #print(predictions)

      optimizer.zero_grad()

      #print("pre shape: ", predictions.shape)
      #print("landmarks sahpe: ", landmarks.shape)
      loss_train_step = euclidean_distance_loss(predictions, landmarks)
      loss_train_step.backward()

      optimizer.step()

      loss_train += loss_train_step.item()
      running_loss = loss_train/step


      print_overwrite(step, len(train_loader), running_loss, 'train')



    with torch.no_grad():
      for step in range(1, len(valid_loader)+1):
        sample = next(iter(valid_loader))
        images = sample['image'].cuda()
        dots = sample['dot'].cuda()
        landmarks = sample['annotations'].cuda()
        landmarks = landmarks.view(32, -1)


        predictions = model(images,dots)


        #loss_test_step = nn.MSELoss()(predictions, landmarks)
        loss_valid_step = euclidean_distance_loss(predictions, landmarks)
        loss_valid += loss_valid_step.item()
        running_loss = loss_valid/step

        print_overwrite(step, len(valid_loader), running_loss, 'valid')


        loss_train /=len(train_loader)
        loss_valid /= len(valid_loader)
        print('\n--------------------------------------------------')
        print('Epoch: {}  Train Loss: {:.4f}  Valid Loss: {:.4f}'.format(epoch, loss_train, loss_valid))
        print('--------------------------------------------------')
        # WandB – Log images in your test dataset automatically, along with predicted and true labels by passing pytorch tensors with image data into wandb.Image
        data = [[x, y] for (x, y) in zip([predictions[step][0],predictions[step][1]], [predictions[step][2],predictions[step][3]] )]
        table = wandb.Table(data=data, columns=["x_position", "y_position"])
        keypoints = wandb.plot.scatter(table, "x_position", "y_position")
        example_images.append(wandb.Image(
                images,keypoints))



    # WandB – wandb.log(a_dict) logs the keys and values of the dictionary passed in and associates the values with a step.
    # You can log anything by passing it to wandb.log, including histograms, custom matplotlib objects, images, video, text, tables, html, pointclouds and other 3D objects.
    # Here we use it to log test accuracy, loss and some test images (along with their true and predicted labels).
    wandb.log({
        "Examples": example_images,
        "Train Loss": loss_train,
        "Valid Loss": loss_valid
        })

# %%
# WandB – Initialize a new run
wandb.init(project="insole_foot_presure")
wandb.watch_called = False # Re-run the model without restarting the runtime, unnecessary after our next release

# WandB – Config is a variable that holds and saves hyperparameters and inputs
config = wandb.config          # Initialize config
config.batch_size = 32       # input batch size for training (default: 64)
config.test_batch_size = 32   # input batch size for testing (default: 1000)
config.epochs = 20             # number of epochs to train (default: 10)
config.lr = 0.1               # learning rate (default: 0.01)
config.momentum = 0.1          # SGD momentum (default: 0.5)
config.no_cuda = False         # disables CUDA training
config.seed = 42               # random seed (default: 42)
config.log_interval = 10     # how many batches to wait before logging training status

def main():
    use_cuda = not config.no_cuda and torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
    kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

    # Set random seeds and deterministic pytorch for reproducibility
    # random.seed(config.seed)       # python random seed
    torch.manual_seed(config.seed) # pytorch random seed
    # numpy.random.seed(config.seed) # numpy random seed
    torch.backends.cudnn.deterministic = True

    # Load the dataset: We're training our CNN on CIFAR10 (https://www.cs.toronto.edu/~kriz/cifar.html)
    # First we define the tranformations to apply to our images
    transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Resize((224,224)),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

    # Now we load our training and test datasets and apply the transformations defined above
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=config.batch_size,
                                              shuffle=True, **kwargs)
    valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=config.test_batch_size,
                                             shuffle=False, **kwargs)

    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=config.test_batch_size,
                                             shuffle=False, **kwargs)

    classes = ('x1', 'y1', 'x2', 'y2')

    # Initialize our model, recursively go over all modules and convert their parameters and buffers to CUDA tensors (if device is set to cuda)
    model = BaseModule(learning_rate = config.lr).to(device)
    optimizer = optim.Adam(model.parameters(), lr=config.lr)

    # WandB – wandb.watch() automatically fetches all layer dimensions, gradients, model parameters and logs them automatically to your dashboard.
    # Using log="all" log histograms of parameter values in addition to gradients
    wandb.watch(model, log="all")

    for epoch in range(1, config.epochs + 1):
        train(config, model, device, train_loader,valid_loader, optimizer, epoch)

    # WandB – Save the model checkpoint. This automatically saves a file to the cloud and associates it with the current run.
    torch.save(model.state_dict(), "model.h6")
    wandb.save('model.h5')

if __name__ == '__main__':
    main()
# Out:
# Finishing last run (ID:xpwlgzju) before initializing another...
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">deft-hill-146</strong> at: <a href='https://wandb.ai/stanley0813382/insole_foot_presure/runs/xpwlgzju' target="_blank">https://wandb.ai/stanley0813382/insole_foot_presure/runs/xpwlgzju</a><br/> View project at: <a href='https://wandb.ai/stanley0813382/insole_foot_presure' target="_blank">https://wandb.ai/stanley0813382/insole_foot_presure</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240415_045630-xpwlgzju/logs</code>
# Successfully finished last run (ID:xpwlgzju). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240415_045818-5f9wb4t2</code>
# Syncing run <strong><a href='https://wandb.ai/stanley0813382/insole_foot_presure/runs/5f9wb4t2' target="_blank">morning-rain-147</a></strong> to <a href='https://wandb.ai/stanley0813382/insole_foot_presure' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/stanley0813382/insole_foot_presure' target="_blank">https://wandb.ai/stanley0813382/insole_foot_presure</a>
#  View run at <a href='https://wandb.ai/stanley0813382/insole_foot_presure/runs/5f9wb4t2' target="_blank">https://wandb.ai/stanley0813382/insole_foot_presure/runs/5f9wb4t2</a>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-fc2a4d27cf1a> in <cell line: 60>()
#      59
#      60 if __name__ == '__main__':
# ---> 61     main()
#
# <ipython-input-110-fc2a4d27cf1a> in main()
#      52
#      53     for epoch in range(1, config.epochs + 1):
# ---> 54         train(config, model, device, train_loader,valid_loader, optimizer, epoch)
#      55
#      56     # WandB – Save the model checkpoint. This automatically saves a file to the cloud and associates it with the current run.
#
# <ipython-input-109-58a6d721392e> in train(args, model, device, train_loader, valid_loader, optimizer, epoch)
#      13
#      14     for step in range(1, len(train_loader)+1):
# ---> 15       sample = next(iter(train_loader))
#      16
#      17       images = sample['image'].cuda()
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     629                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630                 self._reset()  # type: ignore[call-arg]
# --> 631             data = self._next_data()
#     632             self._num_yielded += 1
#     633             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1344             else:
#    1345                 del self._task_info[idx]
# -> 1346                 return self._process_data(data)
#    1347
#    1348     def _try_put_index(self):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1370         self._try_put_index()
#    1371         if isinstance(data, ExceptionWrapper):
# -> 1372             data.reraise()
#    1373         return data
#    1374
#
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py in reraise(self)
#     720             # instantiate since we don't know how to
#     721             raise RuntimeError(msg) from None
# --> 722         raise exception
#     723
#     724
#
# TypeError: Caught TypeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/worker.py", line 308, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py", line 49, in fetch
#     data = self.dataset.__getitems__(possibly_batched_index)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py", line 399, in __getitems__
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataset.py", line 399, in <listcomp>
#     return [self.dataset[self.indices[idx]] for idx in indices]
#   File "<ipython-input-103-09f2abd37cb0>", line 36, in __getitem__
#     sample = self.transform(sample)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py", line 95, in __call__
#     img = t(img)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py", line 137, in __call__
#     return F.to_tensor(pic)
#   File "/usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py", line 141, in to_tensor
#     raise TypeError(f"pic should be PIL Image or ndarray. Got {type(pic)}")
# TypeError: pic should be PIL Image or ndarray. Got <class 'dict'>

# %%
use_cuda = not config.no_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=False)
my_pred_test = dict()
best_model = BaseModule(learning_rate=config.lr).to(device)
best_model.load_state_dict(torch.load('/content/model.h6'))
best_model.eval()
with torch.no_grad():
  for sample in test_loader:
    images = sample['image'].to(device)
    dots = sample['dot'].to(device)

    predictions = best_model(images, dots)
    my_pred_test.update({f:{'x1': predictions[idx][0],'y1':predictions[idx][1], 'x2':predictions[idx][2], 'y2':predictions[idx][3] } for idx ,f in enumerate(sample['file_name'])})
    plt.figure(figsize=(5,10))
    plt.subplot(1, 1, 1)
    plt.imshow(images[0].cpu().numpy().transpose(1, 2, 0).squeeze())
    plt.scatter(predictions[0, 0].cpu().numpy(), predictions[0, 1].cpu().numpy(), s=35, marker='s', c='white', edgecolors='black')
    plt.scatter(predictions[0, 2].cpu().numpy(), predictions[0, 3].cpu().numpy(), s=35, marker='s', c='white', edgecolors='black')


print(my_pred_test)

# %%
import csv

header = ['images', 'x1', 'y1', 'x2', 'y2']
file_name = "final_submission.csv"

# Convert tensors to lists before writing to CSV
data = [
    [key, my_pred_test[key]['x1'].item(), my_pred_test[key]['y1'].item(),
     my_pred_test[key]['x2'].item(), my_pred_test[key]['y2'].item()]
    for key in my_pred_test
]

# Write data to CSV file
with open(file_name, 'w', newline='') as file:
    csvwriter = csv.writer(file)
    csvwriter.writerow(header)  # Write the header
    csvwriter.writerows(data)

print(f"Data has been written to {file_name}")
# Out:
# Data has been written to final_submission.csv

# %%
tmp = pd.read_csv('final_submission.csv')
print(tmp)
# Out:
#              images         x1          y1         x2          y2
# 0    image_0001.png  58.437744  121.054840  78.375092  376.212006
# 1    image_0002.png  52.949627  124.883743  18.153059  371.370972
# 2    image_0003.png  57.748573  142.588776  80.188690  378.674194
# 3    image_0004.png  55.173271  138.075302  19.782228  372.447327
# 4    image_0005.png  62.580132  146.012436  74.545341  371.318573
# ..              ...        ...         ...        ...         ...
# 995  image_0996.png  59.360458  120.251556  26.293398  363.753052
# 996  image_0997.png  61.645828  138.651138  80.316772  378.138641
# 997  image_0998.png  57.209732  127.354065  21.126429  379.815735
# 998  image_0999.png  59.826637  127.073349  76.950882  377.981842
# 999  image_1000.png  54.493614  113.116348  27.421278  380.061676
#
# [1000 rows x 5 columns]
